# %%
import json
import re

# %%
json_text = str(
{
  "main_topics": [
    {
      "title": "Introduction to Python",
      "sub_topics": [
        {
          "title": "Setting Up Python Environment"
        },
        {
          "title": "Basic Syntax and Data Types"
        },
        {
          "title": "Variables and Operators"
        },
        {
          "title": "Control Structures (if, for, while)"
        }
      ]
    },
    {
      "title": "Data Structures in Python",
      "sub_topics": [
        {
          "title": "Lists and Tuples"
        },
        {
          "title": "Dictionaries and Sets"
        },
        {
          "title": "List Comprehensions"
        },
        {
          "title": "Working with Strings"
        }
      ]
    },
    {
      "title": "Functions and Modules",
      "sub_topics": [
        {
          "title": "Defining Functions"
        },
        {
          "title": "Function Arguments and Return Values"
        },
        {
          "title": "Lambda Functions"
        },
        {
          "title": "Creating and Using Modules"
        }
      ]
    },
    {
      "title": "File Handling",
      "sub_topics": [
        {
          "title": "Reading and Writing Files"
        },
        {
          "title": "Working with CSV Files"
        },
        {
          "title": "Handling Exceptions"
        },
        {
          "title": "Context Managers"
        }
      ]
    },
    {
      "title": "Introduction to Data Analysis",
      "sub_topics": [
        {
          "title": "NumPy Basics"
        },
        {
          "title": "Pandas for Data Manipulation"
        },
        {
          "title": "Data Visualization with Matplotlib"
        },
        {
          "title": "Exploratory Data Analysis (EDA)"
        }
      ]
    },
    {
      "title": "Web Development with Python",
      "sub_topics": [
        {
          "title": "Introduction to Flask/Django Frameworks"
        },
        {
          "title": "Setting Up a Web Application"
        },
        {
          "title": "Routing and URL Handling"
        },
        {
          "title": "Templates and Static Files"
        }
      ]
    },
    {
      "title": "APIs and Web Scraping",
      "sub_topics": [
        {
          "title": "Understanding APIs and RESTful Services"
        },
        {
          "title": "Making HTTP Requests with Requests Library"
        },
        {
          "title": "Web Scraping with BeautifulSoup"
        },
        {
          "title": "Handling JSON Data"
        }
      ]
    },
    {
      "title": "Advanced Python Concepts",
      "sub_topics": [
        {
          "title": "Object-Oriented Programming (OOP)"
        },
        {
          "title": "Decorators and Generators"
        },
        {
          "title": "Understanding Python Iterators"
        },
        {
          "title": "Testing and Debugging Techniques"
        }
      ]
    },
    {
      "title": "Project Work",
      "sub_topics": [
        {
          "title": "Building a Simple Data Analysis Project"
        },
        {
          "title": "Creating a Basic Web Application"
        },
        {
          "title": "Integrating Data Analysis into Web Apps"
        },
        {
          "title": "Version Control with Git"
        }
      ]
    }
  ]
}
)

# %%
type(json_text)
# Out:
# str

# %%
parsed_json = json.loads(json_text.replace("'", '"'))
type(parsed_json)
# Out:
# dict

# %%
parsed_json
# Out:
# {'main_topics': [{'title': 'Introduction to Python',
#    'sub_topics': [{'title': 'Setting Up Python Environment'},
#     {'title': 'Basic Syntax and Data Types'},
#     {'title': 'Variables and Operators'},
#     {'title': 'Control Structures (if, for, while)'}]},
#   {'title': 'Data Structures in Python',
#    'sub_topics': [{'title': 'Lists and Tuples'},
#     {'title': 'Dictionaries and Sets'},
#     {'title': 'List Comprehensions'},
#     {'title': 'Working with Strings'}]},
#   {'title': 'Functions and Modules',
#    'sub_topics': [{'title': 'Defining Functions'},
#     {'title': 'Function Arguments and Return Values'},
#     {'title': 'Lambda Functions'},
#     {'title': 'Creating and Using Modules'}]},
#   {'title': 'File Handling',
#    'sub_topics': [{'title': 'Reading and Writing Files'},
#     {'title': 'Working with CSV Files'},
#     {'title': 'Handling Exceptions'},
#     {'title': 'Context Managers'}]},
#   {'title': 'Introduction to Data Analysis',
# ...

# %%
for main in parsed_json['main_topics']:
    print(main['sub_topics'])
    print()
# Out:
# [{'title': 'Setting Up Python Environment'}, {'title': 'Basic Syntax and Data Types'}, {'title': 'Variables and Operators'}, {'title': 'Control Structures (if, for, while)'}]
#
# [{'title': 'Lists and Tuples'}, {'title': 'Dictionaries and Sets'}, {'title': 'List Comprehensions'}, {'title': 'Working with Strings'}]
#
# [{'title': 'Defining Functions'}, {'title': 'Function Arguments and Return Values'}, {'title': 'Lambda Functions'}, {'title': 'Creating and Using Modules'}]
#
# [{'title': 'Reading and Writing Files'}, {'title': 'Working with CSV Files'}, {'title': 'Handling Exceptions'}, {'title': 'Context Managers'}]
#
# [{'title': 'NumPy Basics'}, {'title': 'Pandas for Data Manipulation'}, {'title': 'Data Visualization with Matplotlib'}, {'title': 'Exploratory Data Analysis (EDA)'}]
#
# [{'title': 'Introduction to Flask/Django Frameworks'}, {'title': 'Setting Up a Web Application'}, {'title': 'Routing and URL Handling'}, {'title': 'Templates and Static Files'}]
#
# ...
